# %% [markdown]
# Using what we have learned in Numpy Module to analyze SP500.csv file with Numpy array
# operations.  Please find answers to the following questions:
#
# the highest daily gain and its date, the highest daily loss and its date,
#
#
# the most daily transaction volume and its date,
#
# a monthly report for year 2017-2018, which has monthly average open price, close price, transaction volume and gain/loss, and a query to find all of the months which have certain range of open prices
#
# a yearly report which has annual average open price, close price, transaction volume and gain/loss from 1950 to 2018, and the most profitable year,
#
# a every other five year report which has every five year average open price, close price, transaction volume and gain/loss from 1950 to 2018, and the most profitable five year,

# %% [markdown]
# ##### Members: Noah Little, Zach Healy, Jack Stout, Jacob Thieret, Justin Kehoe, Collyn Rouggly, and Momoh Brema
# ##### Group 2

# %%
import numpy as np

dates, opens, highs, lows, closes, adj, volume = np.loadtxt("SP500.csv", dtype={
    'names': ("date", 'Open', 'High', 'Low', 'Close', 'adj Close', 'Volume'),
    'formats': ("datetime64[D]", float, float, float, float, float, float)},
                                                            converters={0: np.datetime64},
                                                            delimiter=',',
                                                            skiprows=1,
                                                            unpack=True)

# the highest daily gain and its date, the highest daily loss and its date
print(f'Low: {lows.min()} date: {dates[lows.argmin()]}')
print(f'High: {highs.max()} date: {dates[highs.argmax()]}')

# the most daily transaction volume and its date
max_volume_index = volume.argmax()

max_volume = volume[max_volume_index]
max_volume_date = dates[max_volume_index]

print(f'Max volume: {max_volume} date: {max_volume_date}')

# annual report from 1950-2018 to find the annual open price, closing price, transaction volume,
# and the gain/loss expressed as a percent, and the most profitable year
print("Annual report")

start_datetime = np.datetime64("1950-01-01")
end_datetime = np.datetime64("2019-01-01")

year_filter = np.logical_and(dates >= start_datetime.astype("datetime64[D]"),
                             dates < end_datetime.astype("datetime64[D]"))

filtered_dates = dates[year_filter]
filtered_opens = opens[year_filter]
filtered_closes = closes[year_filter]
filtered_volumes = volume[year_filter]

yearly_opens = []
yearly_closes = []
yearly_volumes = []
yearly_gains = []

for year in range(1950, 2019):

    year_start = np.datetime64(str(year), 'Y')
    year_end = year_start + np.timedelta64(1, 'Y')

    year_filter = np.logical_and(filtered_dates >= year_start, filtered_dates < year_end)

    year_dates = filtered_dates[year_filter]
    year_opens = filtered_opens[year_filter]
    year_closes = filtered_closes[year_filter]
    year_volumes = filtered_volumes[year_filter]

    average_open = round(np.average(year_opens), 2)
    average_close = round(np.average(year_closes), 2)
    average_volume = round(np.average(year_volumes))
    percent_change = round((year_closes[-1]-year_opens[0])/year_opens[0]*100, 2)

    yearly_opens.append(average_open)
    yearly_closes.append(average_close)
    yearly_volumes.append(average_volume)
    yearly_gains.append(percent_change)
    
    print(f"Year {year} Report:")
    print(f"Average open: ${average_open}")
    print(f"Average close: ${average_close}")
    print(f"Average volume: {average_volume}")
    print(f"Percent change: {percent_change}%\n")

most_profitable_year = 1950 + np.argmax(yearly_gains)
print(f"Most profitable year: {most_profitable_year} ({yearly_gains[most_profitable_year-1950]}%)")

# 5-year interval report from 1950-2018 to find the open price, closing price, transaction volume,
# and the gain/loss expressed as a percent
print("5-Year Interval Report")

start_year = 1950
end_year = 2018
interval = 5

for year in range(start_year, end_year, interval):

    start_datetime = np.datetime64(str(year), 'Y')
    end_datetime = start_datetime + np.timedelta64(interval, 'Y')

    year_filter = np.logical_and(dates >= start_datetime.astype("datetime64[D]"),
                                 dates < end_datetime.astype("datetime64[D]"))

    interval_dates = dates[year_filter]
    interval_opens = opens[year_filter]
    interval_closes = closes[year_filter]
    interval_volumes = volume[year_filter]

    if len(interval_dates) > 0:
        interval_gain = round((interval_closes[-1] - interval_opens[0]) / interval_opens[0] * 100, 2)

        print(f"{year}-{year+interval-1} Report:")
        print(f"Open: ${interval_opens[0]:,.2f}")
        print(f"Close: ${interval_closes[-1]:,.2f}")
        print(f"Volume: {interval_volumes.sum():,.0f}")
        print(f"Gain/Loss: {interval_gain}%\n")
# Out:
# Low: 16.66 date: 1950-01-03
# High: 2872.870117 date: 2018-01-26
# Max volume: 11456230000.0 date: 2008-10-10
# Annual report
# Year 1950 Report:
# Average open: $18.4
# Average close: $18.4
# Average volume: 2009237
# Percent change: 22.63%
#
# Year 1951 Report:
# Average open: $22.32
# Average close: $22.32
# Average volume: 1717590
# Percent change: 14.44%
#
# Year 1952 Report:
# Average open: $24.5
# Average close: $24.5
# Average volume: 1308160
# Percent change: 11.64%
#
# Year 1953 Report:
# Average open: $24.72
# Average close: $24.72
# Average volume: 1413147
# Percent change: -6.52%
#
# Year 1954 Report:
# Average open: $29.72
# Average close: $29.72
# Average volume: 2269762
# Percent change: 44.21%
#
# Year 1955 Report:
# Average open: $40.5
# Average close: $40.5
# Average volume: 2573214
# Percent change: 23.76%
#
# Year 1956 Report:
# Average open: $46.64
# Average close: $46.64
# Average volume: 2214462
# Percent change: 3.34%
#
# Year 1957 Report:
# Average open: $44.42
# Average close: $44.42
# Average volume: 2217143
# Percent change: -13.44%
#
# Year 1958 Report:
# Average open: $46.2
# Average close: $46.2
# Average volume: 2962937
# Percent change: 36.9%
#
# Year 1959 Report:
# Average open: $57.42
# Average close: $57.42
# Average volume: 3241304
# Percent change: 8.03%
#
# Year 1960 Report:
# Average open: $55.85
# Average close: $55.85
# Average volume: 3041429
# Percent change: -3.0%
#
# Year 1961 Report:
# Average open: $66.27
# Average close: $66.27
# Average volume: 4071440
# Percent change: 24.28%
#
# Year 1962 Report:
# Average open: $62.36
# Average close: $62.32
# Average volume: 3828651
# Percent change: -11.81%
#
# Year 1963 Report:
# Average open: $69.82
# Average close: $69.86
# Average volume: 4571235
# Percent change: 18.89%
#
# Year 1964 Report:
# Average open: $81.33
# Average close: $81.37
# Average volume: 4885850
# Percent change: 12.97%
#
# Year 1965 Report:
# Average open: $88.13
# Average close: $88.16
# Average volume: 6172063
# Percent change: 9.06%
#
# Year 1966 Report:
# Average open: $85.23
# Average close: $85.18
# Average volume: 7528929
# Percent change: -13.09%
#
# Year 1967 Report:
# Average open: $91.88
# Average close: $91.96
# Average volume: 10074980
# Percent change: 20.09%
#
# Year 1968 Report:
# Average open: $98.35
# Average close: $98.38
# Average volume: 12967699
# Percent change: 7.66%
#
# Year 1969 Report:
# Average open: $97.82
# Average close: $97.77
# Average volume: 11387920
# Percent change: -11.36%
#
# Year 1970 Report:
# Average open: $83.15
# Average close: $83.15
# Average volume: 11601299
# Percent change: 0.1%
#
# Year 1971 Report:
# Average open: $98.31
# Average close: $98.32
# Average volume: 15394229
# Percent change: 10.79%
#
# Year 1972 Report:
# Average open: $109.07
# Average close: $109.13
# Average volume: 16483546
# Percent change: 15.63%
#
# Year 1973 Report:
# Average open: $107.51
# Average close: $107.44
# Average volume: 16102302
# Percent change: -17.37%
#
# Year 1974 Report:
# Average open: $82.89
# Average close: $82.78
# Average volume: 13903557
# Percent change: -29.72%
#
# Year 1975 Report:
# Average open: $86.1
# Average close: $86.18
# Average volume: 18566126
# Percent change: 31.38%
#
# Year 1976 Report:
# Average open: $101.96
# Average close: $102.04
# Average volume: 21182253
# Percent change: 19.15%
#
# Year 1977 Report:
# Average open: $98.23
# Average close: $98.18
# Average volume: 20943254
# Percent change: -11.5%
#
# Year 1978 Report:
# Average open: $96.11
# Average close: $96.11
# Average volume: 28571746
# Percent change: 1.06%
#
# Year 1979 Report:
# Average open: $102.95
# Average close: $103.0
# Average volume: 32264269
# Percent change: 12.31%
#
# Year 1980 Report:
# Average open: $118.6
# Average close: $118.71
# Average volume: 44864150
# Percent change: 25.77%
#
# Year 1981 Report:
# Average open: $128.07
# Average close: $128.04
# Average volume: 46857075
# Percent change: -9.73%
#
# Year 1982 Report:
# Average open: $119.64
# Average close: $119.71
# Average volume: 65044980
# Percent change: 14.76%
#
# Year 1983 Report:
# Average open: $160.37
# Average close: $160.47
# Average volume: 85309605
# Percent change: 17.26%
#
# Year 1984 Report:
# Average open: $160.46
# Average close: $160.46
# Average volume: 91223834
# Percent change: 1.4%
#
# Year 1985 Report:
# Average open: $186.65
# Average close: $186.83
# Average volume: 109166905
# Percent change: 26.36%
#
# Year 1986 Report:
# Average open: $236.24
# Average close: $236.39
# Average volume: 141025652
# Percent change: 14.62%
#
# Year 1987 Report:
# Average open: $286.98
# Average close: $287.0
# Average volume: 188926719
# Percent change: 2.03%
#
# Year 1988 Report:
# Average open: $265.77
# Average close: $265.88
# Average volume: 161454625
# Percent change: 12.39%
#
# Year 1989 Report:
# Average open: $322.75
# Average close: $323.05
# Average volume: 165458690
# Percent change: 27.25%
#
# Year 1990 Report:
# Average open: $334.73
# Average close: $334.63
# Average volume: 156848735
# Percent change: -6.56%
#
# Year 1991 Report:
# Average open: $375.84
# Average close: $376.19
# Average volume: 179204150
# Percent change: 26.31%
#
# Year 1992 Report:
# Average open: $415.67
# Average close: $415.75
# Average volume: 202025984
# Percent change: 4.48%
#
# Year 1993 Report:
# Average open: $451.49
# Average close: $451.61
# Average volume: 264712213
# Percent change: 7.06%
#
# Year 1994 Report:
# Average open: $460.45
# Average close: $460.42
# Average volume: 291461667
# Percent change: -1.55%
#
# Year 1995 Report:
# Average open: $541.1
# Average close: $541.72
# Average volume: 346203770
# Percent change: 34.13%
#
# Year 1996 Report:
# Average open: $670.0
# Average close: $670.49
# Average volume: 411420118
# Percent change: 20.26%
#
# Year 1997 Report:
# Average open: $872.52
# Average close: $873.43
# Average volume: 525648142
# Percent change: 31.01%
#
# Year 1998 Report:
# Average open: $1084.48
# Average close: $1085.5
# Average volume: 672261706
# Percent change: 26.67%
#
# Year 1999 Report:
# Average open: $1326.38
# Average close: $1327.33
# Average volume: 808341984
# Percent change: 19.53%
#
# Year 2000 Report:
# Average open: $1427.82
# Average close: $1427.22
# Average volume: 1034489127
# Percent change: -10.14%
#
# Year 2001 Report:
# Average open: $1194.88
# Average close: $1194.18
# Average volume: 1232067661
# Percent change: -13.04%
#
# Year 2002 Report:
# Average open: $994.95
# Average close: $993.93
# Average volume: 1429026389
# Percent change: -23.37%
#
# Year 2003 Report:
# Average open: $964.31
# Average close: $965.23
# Average volume: 1384450992
# Percent change: 26.38%
#
# Year 2004 Report:
# Average open: $1130.26
# Average close: $1130.65
# Average volume: 1423203770
# Percent change: 8.99%
#
# Year 2005 Report:
# Average open: $1207.09
# Average close: $1207.23
# Average volume: 1919903651
# Percent change: 3.0%
#
# Year 2006 Report:
# Average open: $1309.76
# Average close: $1310.46
# Average volume: 2394512988
# Percent change: 13.62%
#
# Year 2007 Report:
# Average open: $1476.96
# Average close: $1477.18
# Average volume: 3227437649
# Percent change: 3.55%
#
# Year 2008 Report:
# Average open: $1222.03
# Average close: $1220.04
# Average volume: 5033222925
# Percent change: -38.47%
#
# Year 2009 Report:
# Average open: $947.02
# Average close: $948.05
# Average volume: 5573207540
# Percent change: 23.49%
#
# Year 2010 Report:
# Average open: $1139.37
# Average close: $1139.97
# Average volume: 4569371389
# Percent change: 12.64%
#
# Year 2011 Report:
# Average open: $1267.62
# Average close: $1267.64
# Average volume: 4109055833
# Percent change: -0.0%
#
# Year 2012 Report:
# Average open: $1378.68
# Average close: $1379.35
# Average volume: 3631677120
# Percent change: 13.29%
#
# Year 2013 Report:
# Average open: $1642.3
# Average close: $1643.8
# Average volume: 3358966627
# Percent change: 29.6%
#
# Year 2014 Report:
# Average open: $1930.75
# Average close: $1931.38
# Average volume: 3354782659
# Percent change: 11.54%
#
# Year 2015 Report:
# Average open: $2061.27
# Average close: $2061.07
# Average volume: 3655629365
# Percent change: -0.73%
#
# Year 2016 Report:
# Average open: $2094.09
# Average close: $2094.65
# Average volume: 3905232024
# Percent change: 9.84%
#
# Year 2017 Report:
# Average open: $2448.28
# Average close: $2449.08
# Average volume: 3412303307
# Percent change: 18.74%
#
# Year 2018 Report:
# Average open: $2715.9
# Average close: $2713.83
# Average volume: 3687696173
# Percent change: -0.51%
#
# Most profitable year: 1954 (44.21%)
# 5-Year Interval Report
# 1950-1954 Report:
# Open: $16.66
# Close: $35.98
# Volume: 2,181,700,000
# Gain/Loss: 115.97%
#
# 1955-1959 Report:
# Open: $36.75
# Close: $59.89
# Volume: 3,329,710,000
# Gain/Loss: 62.97%
#
# 1960-1964 Report:
# Open: $59.91
# Close: $84.75
# Volume: 5,132,620,000
# Gain/Loss: 41.46%
#
# 1965-1969 Report:
# Open: $84.75
# Close: $92.06
# Volume: 11,759,150,000
# Gain/Loss: 8.63%
#
# 1970-1974 Report:
# Open: $92.06
# Close: $68.56
# Volume: 18,554,220,000
# Gain/Loss: -25.53%
#
# 1975-1979 Report:
# Open: $68.65
# Close: $107.94
# Volume: 30,696,980,000
# Gain/Loss: 57.23%
#
# 1980-1984 Report:
# Open: $107.94
# Close: $167.24
# Volume: 84,324,810,000
# Gain/Loss: 54.94%
#
# 1985-1989 Report:
# Open: $167.20
# Close: $353.40
# Volume: 193,531,620,000
# Gain/Loss: 111.36%
#
# 1990-1994 Report:
# Open: $353.40
# Close: $459.27
# Volume: 276,756,510,000
# Gain/Loss: 29.96%
#
# 1995-1999 Report:
# Open: $459.21
# Close: $1,469.25
# Volume: 697,845,170,000
# Gain/Loss: 219.95%
#
# 2000-2004 Report:
# Open: $1,469.25
# Close: $1,211.92
# Volume: 1,633,887,690,000
# Gain/Loss: -17.51%
#
# 2005-2009 Report:
# Open: $1,211.92
# Close: $1,115.10
# Volume: 4,572,779,030,000
# Gain/Loss: -7.99%
#
# 2010-2014 Report:
# Open: $1,116.56
# Close: $2,058.90
# Volume: 4,786,747,760,000
# Gain/Loss: 84.4%
#
# 2015-2019 Report:
# Open: $2,058.90
# Close: $2,669.91
# Volume: 3,060,528,590,000
# Gain/Loss: 29.68%
